# %%
# Out:
# Requirement already satisfied: Flask in c:\users\acer\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\acer\anaconda3\lib\site-packages (from Flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\acer\anaconda3\lib\site-packages (from Flask) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\acer\anaconda3\lib\site-packages (from Flask) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\acer\anaconda3\lib\site-packages (from Flask) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\acer\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, request, jsonify
import real  # Import your machine learning code

app = Flask(__name__)

@app.route('/get_recommendations', methods=['POST'])
def get_recommendations():
    # Get input from the user
    ingredients = request.form.get('recipe_ingredients').split(',')
    prep_time = int(request.form.get('recipe_preptime'))

    recommendations = real.get_recommendations(ingredients, prep_time)

    # Format recommendations as a list of dictionaries
    formatted_recommendations = []
    for recommendation in recommendations:
        formatted_recommendation = {
            'title': recommendation['Name'],
            'ingredients': recommendation['RecipeIngredientParts'],
            'prep_time': recommendation['TotalTime'],
            'calories': recommendation['Calories'],
            'instructions': recommendation['RecipeInstructions'],
        }
        formatted_recommendations.append(formatted_recommendation)

    return jsonify(formatted_recommendations)

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# Enter comma separated list of ingredients: milk
# Enter preparation time in minutes: 10
# Recommended Recipes:
# ------------------------
# Recipe Title: Sugar-Free Peanut Butter Cup Mocha
# Recipe ID: 282308
# Ingredients: milk
# Preparation Time: 7 minutes
# Calories: 0.6
# Instruction: Make expresso and steam milk with an espresso machine. Combine ingredients in a 12 oz. cup. Mix well.
# Category: Beverages
# ------------------------
# Recipe Title: M &amp; M's  Hot Chocolate
# Recipe ID: 349430
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 412.0
# Instruction: Place M & M's in blender. Add hot milk.  Blend until smooth.  Pour into 2 mugs. Top with whipped cream and orange rind slices.
# Category: Beverages
# ------------------------
# Recipe Title: Creamed Turkey - Bye Bye Leftovers!
# Recipe ID: 141033
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 60.2
# Instruction: Cut up any leftover turkey into bite size bits.  Heat the soup slowly and add the cut up turkey. Also add any leftover gravy or dressing. Add the milk -- a little at a time. Heat thoroughly and serve over mashed potatoes. I always serve this with a veggie and leftover cranberry sauce.  Yummy!
# Category: Lunch/Snacks
# ------------------------
# Recipe Title: Homemade Yogurt
# Recipe ID: 9955
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 624.6
# Instruction: Heat the milk to boiling point-212°F. Let cool to just warm-do a wrist test. When no longer\hot\ add the yogurt or yogurt starter and whisk well. There are several methods to go to at this point but I think (IMHO that this is the best. Pour product into a wide-mouth thermos and put the lid on it. Let stand 4-6 hours before refrigerating. Dont shake rattle or roll the thermos while incubating or your going to get yogurt that looks like cottage cheese.
# Category: < 15 Mins
# ------------------------
# Recipe Title: Breakfast Drink for the Young and Not so Young
# Recipe ID: 240947
# Ingredients: milk
# Preparation Time: 4 minutes
# Calories: 189.3
# Instruction: Put all ingredients into a blender or food processor (or jug if using stab blender and blend till well mixed (or pulse blend if you like to leave chunky bits of fruit. Pour into glass and drink (or if in a hurry into a travel mug and go.
# Category: Breakfast
# ------------------------
# Recipe Title: Coffee Foam in Microwave
# Recipe ID: 453146
# Ingredients: milk, milk
# Preparation Time: 2 minutes
# Calories: 0.0
# Instruction: Find a jar with a lid and fill it with as much milk as you normally like in your coffee (or other hot beverage!. The milk should fill the jar no more than half way to allow room for the foam. Shake the jar with the lid on as hard as you can until the milk has become frothy and doubled in size. This takes us about 30 seconds. Take the lid off and microwave for 30 seconds. The foam will rise to the top of the milk and the heat from the microwave will help stabilize it. Pour the milk into your coffee using a spoon to hold back the foam. Then scoop the foam on top!
# Category: Beverages
# ------------------------
# Recipe Title: Chocolate Milk
# Recipe ID: 506056
# Ingredients: milk
# Preparation Time: 8 minutes
# Calories: 90.6
# Instruction: 1. Put the chocolate topping into the milk. 2. Stir until brown! There you go! Chocolate Milk. To make more you'll need : A Blender. A Bottle of Chocolate Topping. And Milk. Put 1 cup of Chocolate topping into the blender. Poor in the milk Blend until frothy. There you go TWO ways to make chocolate milk.
# Category: Beverages
# ------------------------
# Recipe Title: Caramel Macchiato
# Recipe ID: 454820
# Ingredients: milk
# Preparation Time: 4 minutes
# Calories: 157.4
# Instruction: Combine milk syrup and caramel then heat. DO NOT BOIL.Heat in pot whisking till frothy or put in mug and microwave about 90seconds. If heating in pot pour into mug. There should be foam on the top.If microwaving in mug use a milk frother to create foam on top of the milk. Pour prepared espresso into milk. Top with caramel drizzle.
# Category: Beverages
# ------------------------
# Recipe Title: Vanilla-Toffee Latte (Diabetic Version)
# Recipe ID: 460537
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 190.5
# Instruction: Steam  milk. Add syrups to tall cup.   Pour steamed milk into the cup and add brewed espresso and stir. Add some foamed milk to the top.
# Category: Beverages
# ------------------------
# Recipe Title: Chocolate and Milk
# Recipe ID: 358860
# Ingredients: milk
# Preparation Time: 6 minutes
# Calories: 519.5
# Instruction: Put chocolate chips in a small microwave safe dish and microwave on high for 45 seconds. Mix the melted chips up a little bit and slowly drizzle it into the glass of milk.  The chocolate will harden into wierd shaped patties. Eat it with a spoon and DRINK YOUR MILK!
# Category: Candy
# ------------------------
# Recipe Title: Authentic Green Tea Frappuccino
# Recipe ID: 469830
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 189.8
# Instruction: Add milk liquid smoothie base and syrup to blender. Add green tea powder. Add 2/3 of the ice. Blend until ice is broken up into a fine consistency. Check the thickness and add more ice and blend as desired.  Careful not to overblend. Add more syrup if you like it sweeter.
# Category: Smoothies
# ------------------------
# Recipe Title: White Chocolate Boysenberry Cappuccino
# Recipe ID: 272875
# Ingredients: milk, milk
# Preparation Time: 5 minutes
# Calories: 118.0
# Instruction: Steam milk to 160 degrees making froth on top. If you don't have an espresso machine you can just heat the milk in a saucepan on the stove. Set aside. In small 8 oz. cup add white chocolate sauce and boysenberry syrup. Add hot espresso and stir well. Add steamed milk to within a 1/2\ from top of cup. Stir. Add 2-3 Tbl. milk froth and fold in to make it extra creamy. Top with whipped cream white chocolate shavings and even a light drizzling of more boysenberry syrup if desired. Enjoy! :. *Note: This drink does not require any additional sugar added the sauce and syrup are very very sweet.
# Category: Beverages
# ------------------------
# Recipe Title: Acadia's Raspberry Citrus Smoothie
# Recipe ID: 354751
# Ingredients: milk
# Preparation Time: 7 minutes
# Calories: 173.8
# Instruction: In a blender add orange juice pineapple juice milk sherbet and non-dairy creamer. Blend them together for 2-3 minutes on high or until all lumps are gone. Serve immediately!
# Category: Smoothies
# ------------------------
# Recipe Title: Nutella Hot Chocolate
# Recipe ID: 74086
# Ingredients: milk
# Preparation Time: 6 minutes
# Calories: 508.4
# Instruction: Put Nutella and 1/3 cup milk in small saucepan over medium heat. Whisk until blended. Add remaining milk increase heat to medium-high and whisk until hot and frothy.
# Category: Beverages
# ------------------------
# Recipe Title: Tomato Soup W/Milk
# Recipe ID: 416288
# Ingredients: milk
# Preparation Time: 5 minutes
# Calories: 78.5
# Instruction: Combine ingredients and heat through.
# Category: Lunch/Snacks
# ------------------------
# Recipe Title: Zack's Sweet Sweet Chocolate Smoothie
# Recipe ID: 237623
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 121.8
# Instruction: Mix all in blender until smooth. Enjoy!
# Category: Smoothies
# ------------------------
# Recipe Title: Dreamer Steamer
# Recipe ID: 499277
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 222.9
# Instruction: Mix milk with vanilla mint hazelnut caramel Irish cream almond strawberry chocolate or any other syrup that takes your fancy. Heat and mix and froth before dispensing.
# Category: Beverages
# ------------------------
# Recipe Title: Hot Frothy Butterbeer
# Recipe ID: 235420
# Ingredients: milk
# Preparation Time: 8 minutes
# Calories: 404.8
# Instruction: Pour milk into a stovepan and set the burner over medium-high heat. Heat milk until steamy not boiling. Add butterscotch chips and stir with a hand-mixer or froth with a wire whisk until chips are melted and mixture is frothy. Remove from heat and pour the butterbeer into mugs to serve.
# Category: Beverages
# ------------------------
# Recipe Title: Hot Cocoa
# Recipe ID: 151643
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 286.6
# Instruction: Hot---Put milk in an stove-safe container. Warm the milk and add the chocolate syrup and stir. Serve. Cold---Put milkin a cup and stir with chocolate syrup.
# Category: Beverages
# ------------------------
# Recipe Title: Cold Cereal
# Recipe ID: 499383
# Ingredients: milk
# Preparation Time: 4 minutes
# Calories: 78.1
# Instruction: Place the dish you choose on a flat stable surface. Select the flavor of cereal of your liking. Pour cereal into the dish until you reach your desired serving. Next pour milk over the cereal until it is about 3/4 from the top. Mix the cereal slightly with a spoon. Use the same spoon to eat the cereal. Enjoy your delicious quick breakfast.
# Category: Breakfast
# ------------------------
# Recipe Title: Milo Cake
# Recipe ID: 500236
# Ingredients: milk
# Preparation Time: 4 minutes
# Calories: 6.5
# Instruction: add the milo and milk together into the coffee mug. stir until it becomes a gooey mix. place in the microwave on high for 30 secs.
# Category: Australian
# ------------------------
# Recipe Title: Ice Creamless Milkshake
# Recipe ID: 432427
# Ingredients: milk
# Preparation Time: 8 minutes
# Calories: 573.1
# Instruction: Put ice cubes into blender (please remember I use a magic bullet so it's one of those 8oz containers. Pour in Chocolate syrup vanilla syrup and milk. Blend until the noise of big chunks knocking together stops (about 5 minutes. Pour into glass and enjoy! Note: This is very thick so it may require a spoon at first.
# Category: Frozen Desserts
# ------------------------
# Recipe Title: Nacho Cheese Soup Sauce
# Recipe ID: 157206
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 34.7
# Instruction: In small saucepan mix soup and milk. Over medium heat heat through stirring often.
# Category: Sauces
# ------------------------
# Recipe Title: Peppermint Patty Fondue
# Recipe ID: 57664
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 39.0
# Instruction: Coarsely chop candies. Place candies in a medium saucepan and add milk. Warm over low heat until candies are melted stirring frequently. Keep warm for dipping. Important: Serve with OzMartha's Butter Cookies#37986- this combination is to die for!
# Category: Dessert
# ------------------------
# Recipe Title: Warm Woolly Sheep
# Recipe ID: 424960
# Ingredients: milk
# Preparation Time: 3 minutes
# Calories: 70.9
# Instruction: Combine the whisky and Drambuie in a heat-safe mug. Top off with warm milk and stir lightly.  (DH warmed my milk in the microwave 45 seconds to 1 minute and this was a good temperature for me.  He then poured the milk over the liquor.
# Category: Beverages
# ------------------------
# Recipe Title: Chocolate Mocha Milkshake
# Recipe ID: 168098
# Ingredients: milk
# Preparation Time: 7 minutes
# Calories: 117.1
# Instruction: Pour the syrup in the blender. Add the ice cubes and milk. Blend until smooth and enjoy!
# Category: Smoothies
# ------------------------
# Recipe Title: Lana Banana Drink
# Recipe ID: 508199
# Ingredients: milk
# Preparation Time: 2 minutes
# Calories: 179.3
# Instruction: Mix milk with liqueur and add whipped cream. Enjoy!
# Category: Beverages
# ------------------------
# Recipe Title: Classic Caramel Macchiato
# Recipe ID: 80888
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 11.5
# Instruction: Place caramel syrup in the bottom of cup. Top with freshly prepared hot espresso. Spoon very small amount of foamed milk on top of espresso. Avoid getting any milk into espresso if you like it dry. You can add just a wee bit of milk otherwise but not a lot (or it won't be a macchiato anymore!. If desired you can top this with whipped cream and a little bit of warmed caramel topping (squirted from a squeeze bottle is best. Serve at once.
# Category: Beverages
# ------------------------
# Recipe Title: Starbucks Mocha Cookie Crumble Frappuccino Copycat
# Recipe ID: 485721
# Ingredients: milk
# Preparation Time: 10 minutes
# Calories: 267.7
# Instruction: Pour coffee into ice cube trays and freeze for about 3 hours (or overnight. Put 5 or more (depending on size coffee ice cubes into blender and blend until there are no more chunks. Add in the milk and Oreos and blend well. There should be no large chunks of Oreos (it helps to crush the Oreos beforehand. Add Hershey's syrup to taste and blend. Pour into glass and serve immediately. Enjoy!
# Category: Shakes
# ------------------------
# Recipe Title: Magic Potion Punch
# Recipe ID: 218630
# Ingredients: milk
# Preparation Time: 7 minutes
# Calories: 137.0
# Instruction: Stir together chocolate syrup and milk in 4-cup microwavable measure until well blended. Microwave uncovered on High 3 to 4 minutes or until hot. Divide heated mixture among 8 paper \hot\ cups or mugs. Slowly pour about 3 ounces (1/3 cup soda pop into each cup. Top with whipped topping if desired.
# Category: Beverages
# ------------------------
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\acer\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
